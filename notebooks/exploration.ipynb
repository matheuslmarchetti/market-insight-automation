# %%
import yfinance as yf

ticker = "AAPL"

# %%
data_5d = yf.download(ticker, period="5d", interval="1h")

display(data_5d.shape)

display(data_5d.head(10))

display(data_5d.tail(10))

display(data_5d.info())

display(data_5d.describe())
# Out:
# [*********************100%***********************]  1 of 1 completed
# (35, 5)
# Price                           Close        High         Low        Open  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Datetime
# 2026-01-27 14:30:00+00:00  259.845001  261.950012  258.660004  259.140015
# 2026-01-27 15:30:00+00:00  260.720001  261.390015  259.760010  259.859985
# 2026-01-27 16:30:00+00:00  261.309998  261.359985  260.470001  260.720001
# 2026-01-27 17:30:00+00:00  260.255005  261.350006  260.230103  261.300110
# 2026-01-27 18:30:00+00:00  259.875000  260.359985  259.519989  260.269989
# 2026-01-27 19:30:00+00:00  259.380005  260.040009  259.149994  259.875000
# 2026-01-27 20:30:00+00:00  258.269989  259.674988  258.209991  259.385010
# 2026-01-28 14:30:00+00:00  256.089996  258.855011  255.214996  257.559998
# 2026-01-28 15:30:00+00:00  255.490005  256.709991  255.259995  256.059998
# 2026-01-28 16:30:00+00:00  254.820007  255.479996  254.660004  255.470001
#
# Price                        Volume
# Ticker                         AAPL
# Datetime
# 2026-01-27 14:30:00+00:00  10912773
# 2026-01-27 15:30:00+00:00   3262895
# 2026-01-27 16:30:00+00:00   2175987
# 2026-01-27 17:30:00+00:00   1989091
# 2026-01-27 18:30:00+00:00   2504629
# 2026-01-27 19:30:00+00:00   2602286
# 2026-01-27 20:30:00+00:00   2715605
# 2026-01-28 14:30:00+00:00   6604210
# 2026-01-28 15:30:00+00:00   2745774
# 2026-01-28 16:30:00+00:00   2230506
# Price                           Close        High         Low        Open  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Datetime
# 2026-01-30 18:30:00+00:00  257.584991  258.079987  255.750000  256.054993
# 2026-01-30 19:30:00+00:00  259.910004  259.910004  257.410004  257.600006
# 2026-01-30 20:30:00+00:00  259.480011  261.899902  258.000000  259.920013
# 2026-02-02 14:30:00+00:00  265.040009  265.250000  259.204987  260.019989
# 2026-02-02 15:30:00+00:00  264.291809  265.369995  262.309998  265.035004
# 2026-02-02 16:30:00+00:00  264.179993  264.850006  263.809998  264.295013
# 2026-02-02 17:30:00+00:00  265.130005  265.309998  263.779999  264.190002
# 2026-02-02 18:30:00+00:00  267.179993  267.350006  265.010010  265.144989
# 2026-02-02 19:30:00+00:00  268.980011  269.569885  266.820007  267.125000
# 2026-02-02 20:30:00+00:00  269.959991  270.489990  268.839996  268.975006
#
# Price                        Volume
# Ticker                         AAPL
# Datetime
# 2026-01-30 18:30:00+00:00   3652617
# 2026-01-30 19:30:00+00:00   4945206
# 2026-01-30 20:30:00+00:00   9402318
# 2026-02-02 14:30:00+00:00  12724698
# 2026-02-02 15:30:00+00:00   4300486
# 2026-02-02 16:30:00+00:00   2688303
# 2026-02-02 17:30:00+00:00   2603466
# 2026-02-02 18:30:00+00:00   4680086
# 2026-02-02 19:30:00+00:00   6110168
# 2026-02-02 20:30:00+00:00   6031354
# <class 'pandas.DataFrame'>
# DatetimeIndex: 35 entries, 2026-01-27 14:30:00+00:00 to 2026-02-02 20:30:00+00:00
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)
non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 12.7 KB
# None
# Price        Close        High         Low        Open        Volume
# Ticker        AAPL        AAPL        AAPL        AAPL          AAPL
# count   270.000000  270.000000  270.000000  270.000000  2.700000e+02
# mean    232.908427  235.320907  230.303161  232.647364  5.368358e+07
# std      25.925164   25.634408   26.116929   25.942791  2.352529e+07
# min     171.832397  189.691325  168.633346  171.364011  1.791060e+07
# 25%     210.701385  212.288901  208.191489  210.127598  4.015680e+07
# 50%     232.199814  234.355623  229.122896  231.758955  4.728840e+07
# 75%     253.092815  254.689527  249.379609  252.549434  5.622605e+07
# max     286.190002  288.619995  283.299988  286.200012  1.843959e+08

# %% [markdown]
# ## Como obter sua API key do FRED:
#
# 1. **Acesse:** https://fred.stlouisfed.org
# 2. **Clique em "My Account"** (canto superior direito)
# 3. **Cadastre-se gratuitamente** (se ainda não tiver conta)
# 4. **Vá para "Account Settings" → "API Keys"**
# 5. **Clique em "Request API Key"**
# 6. **Preencha o formulário** (uso pessoal/educacional é gratuito)
#
# ## Depois de obter sua chave:
#
# ```python
# from fredapi import Fred
#
# # Substitua com SUA chave
# fred = Fred(api_key="sua_chave_aqui_32_caracteres")
#
# # Buscar dados de inflação
# inflation = fred.get_series("CPIAUCSL")
# print(inflation)
# ```
#
# ## Códigos úteis do FRED:
# - `CPIAUCSL`: Índice de Preços ao Consumidor (inflação)
# - `UNRATE`: Taxa de desemprego
# - `GDP`: PIB
# - `FEDFUNDS`: Taxa de juros dos Fed Funds
#
# A API key gratuita tem limite de 1.200 requisições por hora, o que é suficiente para a maioria dos usos pessoais e educacionais.

# %%
from fredapi import Fred

with open(r"..\..\API_key_FRED.txt", 'r') as f:
    api_key = f.read().strip()

fred = Fred(api_key=api_key)

# %%
inflation = fred.get_series("CPIAUCSL")

display(inflation.shape)

display(inflation.head(10))

display(inflation.tail(10))

display(inflation.info())

display(inflation.describe())
# Out:
# (948,)
# 1947-01-01    21.48
# 1947-02-01    21.62
# 1947-03-01    22.00
# 1947-04-01    22.00
# 1947-05-01    21.95
# 1947-06-01    22.08
# 1947-07-01    22.23
# 1947-08-01    22.40
# 1947-09-01    22.84
# 1947-10-01    22.91
# dtype: float64
# 2025-03-01    319.615
# 2025-04-01    320.321
# 2025-05-01    320.580
# 2025-06-01    321.500
# 2025-07-01    322.132
# 2025-08-01    323.364
# 2025-09-01    324.368
# 2025-10-01        NaN
# 2025-11-01    325.031
# 2025-12-01    326.030
# dtype: float64
# <class 'pandas.Series'>
# DatetimeIndex: 948 entries, 1947-01-01 to 2025-12-01
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 947 non-null    float64
# dtypes: float64(1)
# memory usage: 14.8 KB
# None
# count    947.000000
# mean     123.848383
# std       89.214260
# min       21.480000
# 25%       32.800000
# 50%      109.600000
# 75%      199.550000
# max      326.030000
# dtype: float64

# %%
unrate = fred.get_series("UNRATE")

display(unrate.shape)

display(unrate.head(10))

display(unrate.tail(10))

display(unrate.info())

display(unrate.describe())
# Out:
# (936,)
# 1948-01-01    3.4
# 1948-02-01    3.8
# 1948-03-01    4.0
# 1948-04-01    3.9
# 1948-05-01    3.5
# 1948-06-01    3.6
# 1948-07-01    3.6
# 1948-08-01    3.9
# 1948-09-01    3.8
# 1948-10-01    3.7
# dtype: float64
# 2025-03-01    4.2
# 2025-04-01    4.2
# 2025-05-01    4.3
# 2025-06-01    4.1
# 2025-07-01    4.3
# 2025-08-01    4.3
# 2025-09-01    4.4
# 2025-10-01    NaN
# 2025-11-01    4.5
# 2025-12-01    4.4
# dtype: float64
# <class 'pandas.Series'>
# DatetimeIndex: 936 entries, 1948-01-01 to 2025-12-01
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 935 non-null    float64
# dtypes: float64(1)
# memory usage: 14.6 KB
# None
# count    935.000000
# mean       5.666524
# std        1.706049
# min        2.500000
# 25%        4.300000
# 50%        5.500000
# 75%        6.700000
# max       14.800000
# dtype: float64

# %%
pib = fred.get_series("GDP")

display(pib.shape)

display(pib.head(10))

display(pib.tail(10))

display(pib.info())

display(pib.describe())
# Out:
# (319,)
# 1946-01-01        NaN
# 1946-04-01        NaN
# 1946-07-01        NaN
# 1946-10-01        NaN
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# 1948-04-01    272.567
# dtype: float64
# 2023-04-01    27530.055
# 2023-07-01    28074.846
# 2023-10-01    28424.722
# 2024-01-01    28708.161
# 2024-04-01    29147.044
# 2024-07-01    29511.664
# 2024-10-01    29825.182
# 2025-01-01    30042.113
# 2025-04-01    30485.729
# 2025-07-01    31098.027
# dtype: float64
# <class 'pandas.Series'>
# DatetimeIndex: 319 entries, 1946-01-01 to 2025-07-01
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 315 non-null    float64
# dtypes: float64(1)
# memory usage: 5.0 KB
# None
# count      315.000000
# mean      7675.441851
# std       8069.026559
# min        243.164000
# 25%        826.470000
# 50%       4545.340000
# 75%      13461.682000
# max      31098.027000
# dtype: float64

# %%
fedfunds = fred.get_series("FEDFUNDS")

display(fedfunds.shape)

display(fedfunds.head(10))

display(fedfunds.tail(10))

display(fedfunds.info())

display(fedfunds.describe())
# Out:
# (859,)
# 1954-07-01    0.80
# 1954-08-01    1.22
# 1954-09-01    1.07
# 1954-10-01    0.85
# 1954-11-01    0.83
# 1954-12-01    1.28
# 1955-01-01    1.39
# 1955-02-01    1.29
# 1955-03-01    1.35
# 1955-04-01    1.43
# dtype: float64
# 2025-04-01    4.33
# 2025-05-01    4.33
# 2025-06-01    4.33
# 2025-07-01    4.33
# 2025-08-01    4.33
# 2025-09-01    4.22
# 2025-10-01    4.09
# 2025-11-01    3.88
# 2025-12-01    3.72
# 2026-01-01    3.64
# dtype: float64
# <class 'pandas.Series'>
# DatetimeIndex: 859 entries, 1954-07-01 to 2026-01-01
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 859 non-null    float64
# dtypes: float64(1)
# memory usage: 13.4 KB
# None
# count    859.000000
# mean       4.602678
# std        3.541000
# min        0.050000
# 25%        1.910000
# 50%        4.320000
# 75%        6.125000
# max       19.100000
# dtype: float64

# %%
import feedparser

rss_url = "https://news.google.com/rss/search?q=AAPL+stock"
feed = feedparser.parse(rss_url)

for entry in feed.entries[:5]:
    print(entry.title)
# Out:
# Why JPMorgan Says Apple’s (AAPL) Results Should Calm Investor Nerves - Yahoo Finance
# What's Driving The Jump In Apple Stock? - Benzinga
# Apple CEO sends blunt message iPhone 18 fans can’t ignore - thestreet.com
# AAPL Hold, MSFT Buy Upgrades – Which Tech Giant Wins? - TipRanks
# Stocks making the biggest moves midday: Newmont, Apple, Sandisk, Deckers Outdoor & more - CNBC
